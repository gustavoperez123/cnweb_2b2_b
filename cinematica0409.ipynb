# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoperez123/cnweb_2b2_b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calcVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velMedia

# %% [markdown]
# teste de serviço: velocidade media

# %%
print('Velocidade Média: ',calcVelMedia(50, 4))
# Out:
# Velocidade Média:  12.5

# %% [markdown]
# # Fórmula da aceleração

# %%
def calcularVelMedia(Velocidade, Tempo):
  velMedia = (Velocidade / Tempo)
  return velMedia
  print( "Aceleração =", calculaVelMedia(15, 2))

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %%
def calcularPosicaoMU(posicao_inicial, vel, temp):
  posicao_final = posicao_inicial + (vel * temp)
  return posicao_final

# %% [markdown]
# ## Função horária do deslocamento

# %%
def calcularDeslocamento(vel, temp):
  deslocamento = vel * temp
  return deslocamento
  print("Função horaria ", calcularDeslocamento(15, 2))

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %%
def calcularVelocidadeMUV(velocidade_inicial, aceleracao, tempo):

  velocidade_final = velocidade_inicial + (aceleracao * tempo)
  return velocidade_final
  print ("Movimento Variado ", calcularVelocidadeMUV(15, 2, 2))

# %% [markdown]
# ## Função horária da posição

# %% [markdown]
# ## Equação de Torricelli

# %%
import math

def calcTorricelli(vZero, acel, desloc):
  t = 2 * acel * desloc
  vFinal = t + vZero
  res = round(math.sqrt(vFinal), 2)
  return res

# %% [markdown]
# # Fórmula do movimento vertical

# %% [markdown]
# ## Equação de Torricelli para lançamento vertical

# %% [markdown]
# ## Velocidade vertical em função do tempo

# %% [markdown]
# ## Posição vertical em função do tempo
